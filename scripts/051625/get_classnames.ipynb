# %%
import os
import json
import numpy as np

# os.chdir("/home/zhang.14217/bioclip-dev")
# os.chdir("#### YOUR WORKING DIRECTORY ####")

train_path = "/users/PAS2119/hou/ICICLE/ICICLE-Benchmark/config/data/ENO/ENO_E06_scientific_name/train.json"
test_path = "/users/PAS2119/hou/ICICLE/ICICLE-Benchmark/config/data/ENO/ENO_E06_scientific_name/test.json"

train_json = json.load(open(train_path))
test_json = json.load(open(test_path))

# %%
all_class_names = set()

for ckp in train_json:
    ckp_d = train_json[ckp]
    for d in ckp_d:
        class_name = d["class_name"]
        all_class_names.add(class_name)

for ckp in test_json:
    ckp_d = test_json[ckp]
    for d in ckp_d:
        class_name = d["class_name"]
        all_class_names.add(class_name)

# %%
for n in all_class_names:
    print(f"  - {n}")
# Out:
#   - vertebrata
#   - tragelaphus oryx
#   - crocuta crocuta
#   - equus quagga
#   - giraffa camelopardalis
#   - papio
#   - loxodonta africana
#   - syncerus caffer
#   - aepyceros melampus
#   - phacochoerus africanus
